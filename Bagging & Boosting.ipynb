# %% [markdown]
# # Types of Esemble Learning

# %% [markdown]
# ## 1. Bagging
# Two types of Bagging Algorithm
# 1 . Bagging meta Estimator (in this method we choose any model)
# 2 . Random Forest

# %% [markdown]
# 1 .Bagging (Bagging meta Estimator Classifier)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv(r'C:\Users\Muhammad Uzair\Downloads\Datasets\placement.csv')
dataset.head()
# Out:
#    Unnamed: 0  cgpa  score  placement
# 0           0   6.8    123          1
# 1           1   5.9    106          0
# 2           2   5.3    121          0
# 3           3   7.4    132          1
# 4           4   5.8    142          0

# %%
dataset.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   cgpa       100 non-null    float64
#  1   score      100 non-null    int64
#  2   placement  100 non-null    int64
# dtypes: float64(1), int64(2)
# memory usage: 2.5 KB

# %%
sns.scatterplot(x='cgpa', y='score', hue='placement', data=dataset)
plt.show()

# %%
x = dataset[['cgpa', 'score']]
y = dataset['placement']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# ## Bagging Classification Algorithm

# %%
from sklearn.ensemble import BaggingClassifier

# %%
bagging_model = BaggingClassifier(estimator=SVC(), n_estimators=10, random_state=42)
bagging_model.fit(x_train, y_train)
# Out:
# BaggingClassifier(estimator=SVC(), random_state=42)

# %%
bagging_model.score(x_train, y_train)*100 ,bagging_model.score(x_test, y_test)*100
# Out:
# (56.25, 40.0)

# %% [markdown]
# ## Without Baging

# %%
from sklearn.svm import SVC
svc = SVC(kernel='linear', random_state=42)
svc.fit(x_train, y_train)
# Out:
# SVC(kernel='linear', random_state=42)

# %%
svc.score(x_train, y_train)*100 ,svc.score(x_test, y_test)*100
# Out:
# (91.25, 95.0)

# %% [markdown]
# # Bagging Regressor

# %%
import pandas as pd
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
dataset1 = pd.read_csv(r'C:\Users\Muhammad Uzair\Downloads\Datasets\Salary_dataset.csv') 
dataset1.head()
# Out:
#    YearsExperience  Salary
# 0              1.2   39344
# 1              1.4   46206
# 2              1.6   37732
# 3              2.1   43526
# 4              2.3   39892

# %%
x1 =dataset1[['YearsExperience']]
y1 = dataset1['Salary']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# ## Bagging Algorithm Regressor

# %%
from sklearn.ensemble import BaggingRegressor
from sklearn.linear_model import LinearRegression
bagging_regressor = BaggingRegressor(estimator=LinearRegression(), n_estimators=10, random_state=42)
bagging_regressor.fit(x_train, y_train)
# Out:
# BaggingRegressor(estimator=LinearRegression(), random_state=42)

# %%
bagging_regressor.score(x_train, y_train)*100 ,bagging_regressor.score(x_test, y_test)*100
# Out:
# (67.44450238699258, 63.08138056270245)

# %% [markdown]
# ## Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
rf_regressor = RandomForestRegressor(n_estimators=70, random_state=42)
rf_regressor.fit(x_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=70, random_state=42)

# %%
rf_regressor.score(x_train, y_train)*100 ,rf_regressor.score(x_test, y_test)*100
# Out:
# (97.67551020408163, 51.17142857142857)

# %% [markdown]
# ## Without Bagging

# %%
li = LinearRegression()
li.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
li.score(x_train, y_train)*100 ,li.score(x_test, y_test)*100
# Out:
# (67.47771329296806, 64.28262186104571)
